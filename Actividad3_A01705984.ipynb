# %% [markdown]
# <a href="https://colab.research.google.com/github/diegarza/ValoresAtipicos/blob/main/Actividad3_A01705984.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Gastos y costos 20-23.xlsx')

# %%
# Vemos con qué estamos trabajando
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3347 entries, 0 to 3346
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CALOR Y CONTROL S.A DE C.V  3344 non-null   object
#  1   Unnamed: 1                  3154 non-null   object
#  2   Unnamed: 2                  3343 non-null   object
#  3   Unnamed: 3                  3343 non-null   object
#  4   Unnamed: 4                  3343 non-null   object
#  5   Unnamed: 5                  3343 non-null   object
#  6   Unnamed: 6                  841 non-null    object
#  7   Unnamed: 7                  3343 non-null   object
#  8   Unnamed: 8                  2952 non-null   object
#  9   Unnamed: 9                  3309 non-null   object
#  10  Unnamed: 10                 3075 non-null   object
#  11  Unnamed: 11                 3343 non-null   object
#  12  Unnamed: 12                 3343 non-null   object
#  13  GASTO                       3346 non-null   object
#  14  10418041.6                  3346 non-null   object
#  15  Unnamed: 15                 3342 non-null   object
#  16  Unnamed: 16                 3343 non-null   object
#  17  Unnamed: 17                 22 non-null     object
#  18  Unnamed: 18                 3343 non-null   object
# dtypes: object(19)
# memory usage: 496.9+ KB

# %%
df.head()
# Out:
#   CALOR Y CONTROL S.A DE C.V Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           DEDUCCIONES 2020        NaN        NaN        NaN        NaN
# 1                        NaN        NaN        NaN        NaN        NaN
# 2                        NaN        NaN        NaN        NaN        NaN
# 3                        NaN        NaN        NaN        NaN        NaN
# 4                      FECHA      FOLIO       UUID        RFC  PROVEEDOR
#
#    Unnamed: 5 Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0         NaN        NaN          NaN        NaN        NaN         NaN
# 1         NaN        NaN          NaN        NaN        NaN         NaN
# 2         NaN        NaN          NaN        NaN        NaN         NaN
# 3         NaN        NaN          NaN        NaN        NaN         NaN
# 4  TIPO GASTO      GASTO  DESCRIPCION         TC    IMPORTE         IVA
#
#   Unnamed: 11 Unnamed: 12     GASTO   10418041.6 Unnamed: 15 Unnamed: 16  \
# 0         NaN         NaN       IVA  1597941.439         NaN         NaN
# 1         NaN         NaN   RET IVA     198890.4         NaN         NaN
# 2         NaN         NaN   RET ISR     66039.89         NaN         NaN
# 3         NaN         NaN       NaN          NaN         NaN         NaN
# 4     RET ISR     RET IVA  TOTAL MX    TOTAL SAT        TIPO      STATUS
#
#   Unnamed: 17 Unnamed: 18
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4      POLIZA    Columna1

# %%
# Eliminamos las primeras 4 filas
df = df[4:]
df.head()
# Out:
#   CALOR Y CONTROL S.A DE C.V              Unnamed: 1  \
# 4                      FECHA                   FOLIO
# 5        2020-01-01 00:00:00                   39408
# 6        2020-01-01 00:00:00  0001010100750847116902
# 7        2020-01-01 00:00:00  0001010100752163714102
# 8        2020-01-01 00:00:00                    3663
#
#                              Unnamed: 2    Unnamed: 3  \
# 4                                  UUID           RFC
# 5  BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 6  85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 7  BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 8  EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
#
#                                           Unnamed: 4            Unnamed: 5  \
# 4                                          PROVEEDOR            TIPO GASTO
# 5                                ARSI RENTA SA DE CV            MAQUINARIA
# 6                     BANCO NACIONAL DE MEXICO, S.A.     COMISION BANCARIA
# 7                     BANCO NACIONAL DE MEXICO, S.A.     COMISION BANCARIA
# 8  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...  HONORARIOS CONTABLES
#
#   Unnamed: 6                                         Unnamed: 7 Unnamed: 8  \
# 4      GASTO                                        DESCRIPCION         TC
# 5        NaN  Descripción: REVOLVEDORA, Modelo: ULTRAMP9A, M...          1
# 6        NaN                                   COMISION COBRADA          1
# 7        NaN                                   COMISION COBRADA          1
# 8        NaN   HONORARIOS CONTABLES\nDEL MES DE ENERO DEL 2020.          1
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12     GASTO 10418041.6  \
# 4    IMPORTE         IVA     RET ISR     RET IVA  TOTAL MX  TOTAL SAT
# 5          0     2248.28           0           0   2248.28      16300
# 6        490        78.4           0           0     568.4      568.4
# 7        195        31.2           0           0     226.2      226.2
# 8   10694.25     1711.08           0           0  12405.33   12405.33
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 4        TIPO      STATUS      POLIZA    Columna1
# 5           I     Vigente         NaN    14051.72
# 6           I     Vigente         NaN           0
# 7           I     Vigente         NaN           0
# 8           I     Vigente         NaN           0

# %%
# Hacemos que la primera fila sea la de títulos

df.rename(columns = df.iloc[0], inplace=True)

# %%
df = df[1:]
df.head()
# Out:
#                  FECHA                   FOLIO  \
# 5  2020-01-01 00:00:00                   39408
# 6  2020-01-01 00:00:00  0001010100750847116902
# 7  2020-01-01 00:00:00  0001010100752163714102
# 8  2020-01-01 00:00:00                    3663
# 9  2020-01-01 00:00:00                    2849
#
#                                    UUID           RFC  \
# 5  BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 6  85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 7  BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 8  EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 9  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
#
#                                            PROVEEDOR            TIPO GASTO  \
# 5                                ARSI RENTA SA DE CV            MAQUINARIA
# 6                     BANCO NACIONAL DE MEXICO, S.A.     COMISION BANCARIA
# 7                     BANCO NACIONAL DE MEXICO, S.A.     COMISION BANCARIA
# 8  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...  HONORARIOS CONTABLES
# 9                   ELECTROTERMICA NACIONAL SA DE CV               COMPRAS
#
#   GASTO                                        DESCRIPCION TC   IMPORTE  \
# 5   NaN  Descripción: REVOLVEDORA, Modelo: ULTRAMP9A, M...  1         0
# 6   NaN                                   COMISION COBRADA  1       490
# 7   NaN                                   COMISION COBRADA  1       195
# 8   NaN   HONORARIOS CONTABLES\nDEL MES DE ENERO DEL 2020.  1  10694.25
# 9   NaN                                               Pago  1         0
#
#        IVA RET ISR RET IVA  TOTAL MX TOTAL SAT TIPO   STATUS POLIZA  Columna1
# 5  2248.28       0       0   2248.28     16300    I  Vigente    NaN  14051.72
# 6     78.4       0       0     568.4     568.4    I  Vigente    NaN         0
# 7     31.2       0       0     226.2     226.2    I  Vigente    NaN         0
# 8  1711.08       0       0  12405.33  12405.33    I  Vigente    NaN         0
# 9      NaN       0       0         0         0    P  Vigente    NaN         0

# %%
df.isnull().sum()
# Se observa que existen columnas con muchos valores nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %% [markdown]
# ##Eliminamos valores nulos

# %%
# Vamos a usar bfill
df1 =df.fillna(method="bfill")
df1
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 5    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 6    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 7    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 8    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 9    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3342 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3343 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3344 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3345 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3346 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
#                RFC                                          PROVEEDOR  \
# 5     ARE080115PBA                                ARSI RENTA SA DE CV
# 6     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 7     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 8     PSS120625C86  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...
# 9     ENA7006081P0                   ELECTROTERMICA NACIONAL SA DE CV
# ...            ...                                                ...
# 3342  SQS110113MU0                   SERVICIO QUINTANA SUR S.A DE C.V
# 3343  PSQ790724C90  CIA. PERIODISTICA DEL SOL DE QUERETARO, S.A. D...
# 3344  SQX981027RY5                            SUPER Q, S. A. DE C. V.
# 3345  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 3346  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
#
#                 TIPO GASTO   GASTO  \
# 5               MAQUINARIA  COMPRA
# 6        COMISION BANCARIA  COMPRA
# 7        COMISION BANCARIA  COMPRA
# 8     HONORARIOS CONTABLES  COMPRA
# 9                  COMPRAS  COMPRA
# ...                    ...     ...
# 3342           COMBUSTIBLE   G VTA
# 3343            PUBLICIDAD   G VTA
# 3344             ALIMENTOS   G VTA
# 3345     COMISION BANCARIA  G FINA
# 3346           COMBUSTIBLE   G VTA
#
#                                             DESCRIPCION   TC   IMPORTE  \
# 5     Descripción: REVOLVEDORA, Modelo: ULTRAMP9A, M...  1.0      0.00
# 6                                      COMISION COBRADA  1.0    490.00
# 7                                      COMISION COBRADA  1.0    195.00
# 8      HONORARIOS CONTABLES\nDEL MES DE ENERO DEL 2020.  1.0  10694.25
# 9                                                  Pago  1.0      0.00
# ...                                                 ...  ...       ...
# 3342                                        32011 MAGNA  1.0    129.79
# 3343   82101504-PUBLICIDAD EN PERIODICOSCALOR Y CONTROL  1.0   2284.80
# 3344                  REF VICTORIA GROSELLA 3 LT PET NR  1.0    163.79
# 3345                             COMISIONES E INTERESES  1.0      0.00
# 3346  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  1.0  14889.29
#
#           IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO   STATUS  \
# 5     2248.28      0.0      0.0   2248.28   16300.00    I  Vigente
# 6       78.40      0.0      0.0    568.40     568.40    I  Vigente
# 7       31.20      0.0      0.0    226.20     226.20    I  Vigente
# 8     1711.08      0.0      0.0  12405.33   12405.33    I  Vigente
# 9     5131.03      0.0      0.0      0.00       0.00    P  Vigente
# ...       ...      ...      ...       ...        ...  ...      ...
# 3342    20.21      0.0      0.0    150.00     150.00    I  Vigente
# 3343   365.57      0.0      0.0   2650.37    2650.37    I  Vigente
# 3344    26.21      0.0      0.0    190.00     190.00    I  Vigente
# 3345     0.00      0.0      0.0      0.00       0.00    I  Vigente
# 3346     0.00      0.0      0.0  14889.29   14889.29    I  Vigente
#
#           POLIZA  Columna1
# 5     PE07-ENE20  14051.72
# 6     PE07-ENE20      0.00
# 7     PE07-ENE20      0.00
# 8     PE07-ENE20      0.00
# 9     PE07-ENE20      0.00
# ...          ...       ...
# 3342         NaN      0.00
# 3343         NaN      0.00
# 3344         NaN      0.00
# 3345         NaN      0.00
# 3346         NaN      0.00
#
# [3342 rows x 19 columns]

# %%
df1.isnull().sum()
# Out:
# FECHA             0
# FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO             0
# DESCRIPCION       0
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2898
# Columna1          0
# dtype: int64

# %%
# Como aún faltan valores nulos en la columna de póliza, se aplica ffill

# %%
df2 =df1.fillna(method="ffill")
df2.isnull().sum()
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %%
# Simplificamos
df = df2

# %%
# Hacemos diagrama de caja del df
fig = plt.figure(figsize =(15, 8))
df.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %% [markdown]
# ##Proceso para eliminar outliers

# %% [markdown]
# ###Por desviación estándar

# %%
# Por std dv
y=df
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Columna1     14626.999268
# FECHA                 NaT
# IMPORTE      25212.063736
# IVA           5206.165867
# RET ISR        667.271992
# RET IVA        958.239955
# TC               4.239688
# TOTAL MX     28488.002843
# TOTAL SAT    33250.398514
# dtype: object
# Limite inferior permitido Columna1    -14171.411134
# FECHA                 NaT
# IMPORTE     -18928.758033
# IVA          -4129.109781
# RET ISR       -627.750813
# RET IVA       -839.215179
# TC               -2.12987
# TOTAL MX    -21455.655297
# TOTAL SAT   -25762.462834
# dtype: object
# <ipython-input-137-d0334274d13a>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-137-d0334274d13a>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-137-d0334274d13a>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-137-d0334274d13a>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-137-d0334274d13a>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-137-d0334274d13a>:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
df_nuevo = df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
df_nuevo
# Out:
# <ipython-input-138-ebcaac5b46ec>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_nuevo = df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#      FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO GASTO DESCRIPCION   TC  \
# 5      NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 6      NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 7      NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 8      NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 9      NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# ...    ...   ...  ...  ...       ...        ...   ...         ...  ...
# 3342   NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 3343   NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 3344   NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 3345   NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
# 3346   NaT   NaN  NaN  NaN       NaN        NaN   NaN         NaN  1.0
#
#        IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO STATUS  \
# 5         0.00  2248.28      0.0      0.0   2248.28   16300.00  NaN    NaN
# 6       490.00    78.40      0.0      0.0    568.40     568.40  NaN    NaN
# 7       195.00    31.20      0.0      0.0    226.20     226.20  NaN    NaN
# 8     10694.25  1711.08      0.0      0.0  12405.33   12405.33  NaN    NaN
# 9         0.00  5131.03      0.0      0.0      0.00       0.00  NaN    NaN
# ...        ...      ...      ...      ...       ...        ...  ...    ...
# 3342    129.79    20.21      0.0      0.0    150.00     150.00  NaN    NaN
# 3343   2284.80   365.57      0.0      0.0   2650.37    2650.37  NaN    NaN
# 3344    163.79    26.21      0.0      0.0    190.00     190.00  NaN    NaN
# 3345      0.00     0.00      0.0      0.0      0.00       0.00  NaN    NaN
# 3346  14889.29     0.00      0.0      0.0  14889.29   14889.29  NaN    NaN
#
#      POLIZA  Columna1
# 5       NaN  14051.72
# 6       NaN      0.00
# 7       NaN      0.00
# 8       NaN      0.00
# 9       NaN      0.00
# ...     ...       ...
# 3342    NaN      0.00
# 3343    NaN      0.00
# 3344    NaN      0.00
# 3345    NaN      0.00
# 3346    NaN      0.00
#
# [3342 rows x 19 columns]

# %%
# Eliminamos columnas con datos que no fueron arrojados en el punto antepasado
df_nuevo = df_nuevo.drop(['FECHA','FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TIPO', 'STATUS', 'POLIZA'], axis=1)
df_nuevo
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 5     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 6     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 7     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 8     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 9     1.0      0.00  5131.03      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3342  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3343  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3344  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3345  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3346  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
# Analizamos valores nulos
df_nuevo.isnull().sum()
# Out:
# TC            9
# IMPORTE      66
# IVA          46
# RET ISR      21
# RET IVA      74
# TOTAL MX     65
# TOTAL SAT    45
# Columna1     15
# dtype: int64

# %%
#Reemplazamos valores atípicos del dataframe con promedio
df_limpio=df_nuevo.copy()
df_limpio=df_limpio.fillna(round(df_nuevo.mean(),1))
df_limpio
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 5     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 6     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 7     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 8     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 9     1.0      0.00  5131.03      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3342  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3343  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3344  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3345  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3346  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
# Vemos que no haya nulos
df_limpio.isnull().sum()
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# Columna1     0
# dtype: int64

# %%
# Hacemos diagrama de caja del df
fig = plt.figure(figsize =(15, 8))
df_limpio.plot(kind='box', vert=False)
plt.title("Valores Atípicos del df_limpio")
plt.show()

# %%
columnas = df[['FECHA','FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TIPO', 'STATUS', 'POLIZA']]
df_final_std = pd.concat([columnas, df_limpio], axis=1)
df_final_std
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 5    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 6    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 7    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 8    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 9    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3342 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3343 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3344 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3345 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3346 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
#                RFC                                          PROVEEDOR  \
# 5     ARE080115PBA                                ARSI RENTA SA DE CV
# 6     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 7     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 8     PSS120625C86  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...
# 9     ENA7006081P0                   ELECTROTERMICA NACIONAL SA DE CV
# ...            ...                                                ...
# 3342  SQS110113MU0                   SERVICIO QUINTANA SUR S.A DE C.V
# 3343  PSQ790724C90  CIA. PERIODISTICA DEL SOL DE QUERETARO, S.A. D...
# 3344  SQX981027RY5                            SUPER Q, S. A. DE C. V.
# 3345  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 3346  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
#
#                 TIPO GASTO   GASTO  \
# 5               MAQUINARIA  COMPRA
# 6        COMISION BANCARIA  COMPRA
# 7        COMISION BANCARIA  COMPRA
# 8     HONORARIOS CONTABLES  COMPRA
# 9                  COMPRAS  COMPRA
# ...                    ...     ...
# 3342           COMBUSTIBLE   G VTA
# 3343            PUBLICIDAD   G VTA
# 3344             ALIMENTOS   G VTA
# 3345     COMISION BANCARIA  G FINA
# 3346           COMBUSTIBLE   G VTA
#
#                                             DESCRIPCION TIPO   STATUS  \
# 5     Descripción: REVOLVEDORA, Modelo: ULTRAMP9A, M...    I  Vigente
# 6                                      COMISION COBRADA    I  Vigente
# 7                                      COMISION COBRADA    I  Vigente
# 8      HONORARIOS CONTABLES\nDEL MES DE ENERO DEL 2020.    I  Vigente
# 9                                                  Pago    P  Vigente
# ...                                                 ...  ...      ...
# 3342                                        32011 MAGNA    I  Vigente
# 3343   82101504-PUBLICIDAD EN PERIODICOSCALOR Y CONTROL    I  Vigente
# 3344                  REF VICTORIA GROSELLA 3 LT PET NR    I  Vigente
# 3345                             COMISIONES E INTERESES    I  Vigente
# 3346  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS    I  Vigente
#
#            POLIZA   TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  \
# 5      PE07-ENE20  1.0      0.00  2248.28      0.0      0.0   2248.28
# 6      PE07-ENE20  1.0    490.00    78.40      0.0      0.0    568.40
# 7      PE07-ENE20  1.0    195.00    31.20      0.0      0.0    226.20
# 8      PE07-ENE20  1.0  10694.25  1711.08      0.0      0.0  12405.33
# 9      PE07-ENE20  1.0      0.00  5131.03      0.0      0.0      0.00
# ...           ...  ...       ...      ...      ...      ...       ...
# 3342  NO LOS METI  1.0    129.79    20.21      0.0      0.0    150.00
# 3343  NO LOS METI  1.0   2284.80   365.57      0.0      0.0   2650.37
# 3344  NO LOS METI  1.0    163.79    26.21      0.0      0.0    190.00
# 3345  NO LOS METI  1.0      0.00     0.00      0.0      0.0      0.00
# 3346  NO LOS METI  1.0  14889.29     0.00      0.0      0.0  14889.29
#
#       TOTAL SAT  Columna1
# 5      16300.00  14051.72
# 6        568.40      0.00
# 7        226.20      0.00
# 8      12405.33      0.00
# 9          0.00      0.00
# ...         ...       ...
# 3342     150.00      0.00
# 3343    2650.37      0.00
# 3344     190.00      0.00
# 3345       0.00      0.00
# 3346   14889.29      0.00
#
# [3342 rows x 19 columns]

# %%
# Mandamos a csv
df_final_std.to_csv('desviacion_estandar.csv')

# %% [markdown]
# ###Por rango intercuartílico

# %%
# Eliminamos columnas con datos que no son útiles para el IQR
df2 = df.drop(['FECHA','FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TIPO', 'STATUS', 'POLIZA'], axis=1)
df2
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 5     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 6     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 7     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 8     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 9     1.0      0.00  5131.03      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3342  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3343  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3344  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3345  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3346  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
#Se encuentran cuartiles 0.25 y 0.75
y=df2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC              1.00000
# IMPORTE      6976.21375
# IVA          1170.77250
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX     7983.17750
# TOTAL SAT    8269.28375
# Columna1        0.00000
# dtype: float64
# Limite inferior permitido TC              1.00000
# IMPORTE     -4160.35625
# IVA          -687.92750
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX    -4783.14250
# TOTAL SAT   -4832.96625
# Columna1        0.00000
# dtype: float64

# %%
#Obtenemos datos limpios del Dataframe
df_iqr1 = df2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
df_iqr1
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 5     1.0     0.00     NaN      0.0      0.0   2248.28        NaN       NaN
# 6     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 7     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 8     1.0      NaN     NaN      0.0      0.0       NaN        NaN       0.0
# 9     1.0     0.00     NaN      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3342  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3343  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3344  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3345  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3346  1.0      NaN    0.00      0.0      0.0       NaN        NaN       0.0
#
# [3342 rows x 8 columns]

# %%
# Vemos valores nulos
df_iqr1.isnull().sum()
# Out:
# TC             9
# IMPORTE      424
# IVA          411
# RET ISR       45
# RET IVA      253
# TOTAL MX     420
# TOTAL SAT    426
# Columna1     240
# dtype: int64

# %%
#Reemplazamos valores atípicos con promedio
#Realizamos una copia del dataframe
df_iqr2=df_iqr1.copy()
df_iqr2=df_iqr2.fillna(round(df_iqr1.mean(),1))
df_iqr2
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 5     1.0     0.00  187.40      0.0      0.0   2248.28    1333.00       0.0
# 6     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 7     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 8     1.0  1093.80  187.40      0.0      0.0   1239.10    1333.00       0.0
# 9     1.0     0.00  187.40      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3342  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3343  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3344  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3345  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3346  1.0  1093.80    0.00      0.0      0.0   1239.10    1333.00       0.0
#
# [3342 rows x 8 columns]

# %%
# Hacemos diagrama de caja del df
fig = plt.figure(figsize =(15, 8))
df_iqr2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del df_limpio")
plt.show()

# %%
# Unimos las columnas que habíamos quitado
columnas = df[['FECHA','FOLIO', 'UUID', 'RFC', 'PROVEEDOR', 'TIPO GASTO', 'GASTO', 'DESCRIPCION', 'TIPO', 'STATUS', 'POLIZA']]
df_final = pd.concat([columnas, df_iqr2], axis=1)
df_final
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 5    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 6    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 7    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 8    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 9    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3342 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3343 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3344 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3345 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3346 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
#                RFC                                          PROVEEDOR  \
# 5     ARE080115PBA                                ARSI RENTA SA DE CV
# 6     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 7     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 8     PSS120625C86  PROMOTORA DE SERVICIOS Y SOLUCIONES EMPRESARIA...
# 9     ENA7006081P0                   ELECTROTERMICA NACIONAL SA DE CV
# ...            ...                                                ...
# 3342  SQS110113MU0                   SERVICIO QUINTANA SUR S.A DE C.V
# 3343  PSQ790724C90  CIA. PERIODISTICA DEL SOL DE QUERETARO, S.A. D...
# 3344  SQX981027RY5                            SUPER Q, S. A. DE C. V.
# 3345  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 3346  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
#
#                 TIPO GASTO   GASTO  \
# 5               MAQUINARIA  COMPRA
# 6        COMISION BANCARIA  COMPRA
# 7        COMISION BANCARIA  COMPRA
# 8     HONORARIOS CONTABLES  COMPRA
# 9                  COMPRAS  COMPRA
# ...                    ...     ...
# 3342           COMBUSTIBLE   G VTA
# 3343            PUBLICIDAD   G VTA
# 3344             ALIMENTOS   G VTA
# 3345     COMISION BANCARIA  G FINA
# 3346           COMBUSTIBLE   G VTA
#
#                                             DESCRIPCION TIPO   STATUS  \
# 5     Descripción: REVOLVEDORA, Modelo: ULTRAMP9A, M...    I  Vigente
# 6                                      COMISION COBRADA    I  Vigente
# 7                                      COMISION COBRADA    I  Vigente
# 8      HONORARIOS CONTABLES\nDEL MES DE ENERO DEL 2020.    I  Vigente
# 9                                                  Pago    P  Vigente
# ...                                                 ...  ...      ...
# 3342                                        32011 MAGNA    I  Vigente
# 3343   82101504-PUBLICIDAD EN PERIODICOSCALOR Y CONTROL    I  Vigente
# 3344                  REF VICTORIA GROSELLA 3 LT PET NR    I  Vigente
# 3345                             COMISIONES E INTERESES    I  Vigente
# 3346  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS    I  Vigente
#
#            POLIZA   TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  \
# 5      PE07-ENE20  1.0     0.00  187.40      0.0      0.0   2248.28
# 6      PE07-ENE20  1.0   490.00   78.40      0.0      0.0    568.40
# 7      PE07-ENE20  1.0   195.00   31.20      0.0      0.0    226.20
# 8      PE07-ENE20  1.0  1093.80  187.40      0.0      0.0   1239.10
# 9      PE07-ENE20  1.0     0.00  187.40      0.0      0.0      0.00
# ...           ...  ...      ...     ...      ...      ...       ...
# 3342  NO LOS METI  1.0   129.79   20.21      0.0      0.0    150.00
# 3343  NO LOS METI  1.0  2284.80  365.57      0.0      0.0   2650.37
# 3344  NO LOS METI  1.0   163.79   26.21      0.0      0.0    190.00
# 3345  NO LOS METI  1.0     0.00    0.00      0.0      0.0      0.00
# 3346  NO LOS METI  1.0  1093.80    0.00      0.0      0.0   1239.10
#
#       TOTAL SAT  Columna1
# 5       1333.00       0.0
# 6        568.40       0.0
# 7        226.20       0.0
# 8       1333.00       0.0
# 9          0.00       0.0
# ...         ...       ...
# 3342     150.00       0.0
# 3343    2650.37       0.0
# 3344     190.00       0.0
# 3345       0.00       0.0
# 3346    1333.00       0.0
#
# [3342 rows x 19 columns]

# %%
# Mandamos a csv
df_final.to_csv('iqr.csv')
